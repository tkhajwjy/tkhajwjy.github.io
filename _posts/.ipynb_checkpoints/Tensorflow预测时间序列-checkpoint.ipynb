# %% [markdown]
# # Tensorflow预测时间序列

# %% [markdown]
# * 使用TFTS库（Tensorflow Time Series）
# * AR预测
# * LSTM预测

# %% [markdown]
# 什么是时间序列问题？
#
# 商场人流量的预测、商品价格预测、股价预测等
#
# 时间序列问题一般形式是什么？
#
# 时间点和观察值，时间点可以不连续

# %% [markdown]
# ## TFTS库读时间序列数据
#
# 在训练模型之前，需要将时间序列数据读成Tensor形式。
#
# 读数据两种方式：
# * NumpyReader:从numpy数组读
# * CSVReader:从csv中读

# %% [markdown]
# ## numpy数组中读数据

# %%
import numpy as np
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.contrib.timeseries.python.timeseries import NumpyReader

# %%
# %matplotlib inline
x = np.array(range(1000))
noise = np.random.uniform(-0.2,0.2,1000)
y = np.sin(np.pi * x / 100) + x / 200 + noise
plt.plot(x,y)

# %%
data = {
    tf
}
